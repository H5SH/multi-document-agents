# %%
# %pip install llama-index-agent-openai
# %pip install llama-index-embeddings-openai
# %pip install llama-index-llms-openai
# Out:
# Requirement already satisfied: llama-index-agent-openai in c:\conda\envs\sql_bot\lib\site-packages (0.3.0)
# Requirement already satisfied: llama-index-core<0.12.0,>=0.11.0 in c:\conda\envs\sql_bot\lib\site-packages (from llama-index-agent-openai) (0.11.5)
# Requirement already satisfied: llama-index-llms-openai<0.3.0,>=0.2.0 in c:\conda\envs\sql_bot\lib\site-packages (from llama-index-agent-openai) (0.2.2)
# Requirement already satisfied: openai>=1.14.0 in c:\conda\envs\sql_bot\lib\site-packages (from llama-index-agent-openai) (1.43.0)
# Requirement already satisfied: PyYAML>=6.0.1 in c:\conda\envs\sql_bot\lib\site-packages (from llama-index-core<0.12.0,>=0.11.0->llama-index-agent-openai) (6.0.2)
# Requirement already satisfied: SQLAlchemy>=1.4.49 in c:\conda\envs\sql_bot\lib\site-packages (from SQLAlchemy[asyncio]>=1.4.49->llama-index-core<0.12.0,>=0.11.0->llama-index-agent-openai) (2.0.34)
# Requirement already satisfied: aiohttp<4.0.0,>=3.8.6 in c:\conda\envs\sql_bot\lib\site-packages (from llama-index-core<0.12.0,>=0.11.0->llama-index-agent-openai) (3.10.5)
# Requirement already satisfied: dataclasses-json in c:\conda\envs\sql_bot\lib\site-packages (from llama-index-core<0.12.0,>=0.11.0->llama-index-agent-openai) (0.6.7)
# Requirement already satisfied: deprecated>=1.2.9.3 in c:\conda\envs\sql_bot\lib\site-packages (from llama-index-core<0.12.0,>=0.11.0->llama-index-agent-openai) (1.2.14)
# Requirement already satisfied: dirtyjson<2.0.0,>=1.0.8 in c:\conda\envs\sql_bot\lib\site-packages (from llama-index-core<0.12.0,>=0.11.0->llama-index-agent-openai) (1.0.8)
# Requirement already satisfied: fsspec>=2023.5.0 in c:\conda\envs\sql_bot\lib\site-packages (from llama-index-core<0.12.0,>=0.11.0->llama-index-agent-openai) (2024.9.0)
# Requirement already satisfied: httpx in c:\conda\envs\sql_bot\lib\site-packages (from llama-index-core<0.12.0,>=0.11.0->llama-index-agent-openai) (0.27.2)
# Requirement already satisfied: nest-asyncio<2.0.0,>=1.5.8 in c:\conda\envs\sql_bot\lib\site-packages (from llama-index-core<0.12.0,>=0.11.0->llama-index-agent-openai) (1.6.0)
# Requirement already satisfied: networkx>=3.0 in c:\conda\envs\sql_bot\lib\site-packages (from llama-index-core<0.12.0,>=0.11.0->llama-index-agent-openai) (3.3)
# Requirement already satisfied: nltk>3.8.1 in c:\conda\envs\sql_bot\lib\site-packages (from llama-index-core<0.12.0,>=0.11.0->llama-index-agent-openai) (3.9.1)
# Requirement already satisfied: numpy<2.0.0 in c:\conda\envs\sql_bot\lib\site-packages (from llama-index-core<0.12.0,>=0.11.0->llama-index-agent-openai) (1.26.4)
# Requirement already satisfied: pillow>=9.0.0 in c:\conda\envs\sql_bot\lib\site-packages (from llama-index-core<0.12.0,>=0.11.0->llama-index-agent-openai) (10.4.0)
# Requirement already satisfied: pydantic<3.0.0,>=2.7.0 in c:\conda\envs\sql_bot\lib\site-packages (from llama-index-core<0.12.0,>=0.11.0->llama-index-agent-openai) (2.8.2)
# Requirement already satisfied: requests>=2.31.0 in c:\conda\envs\sql_bot\lib\site-packages (from llama-index-core<0.12.0,>=0.11.0->llama-index-agent-openai) (2.32.3)
# Requirement already satisfied: tenacity!=8.4.0,<9.0.0,>=8.2.0 in c:\conda\envs\sql_bot\lib\site-packages (from llama-index-core<0.12.0,>=0.11.0->llama-index-agent-openai) (8.5.0)
# Requirement already satisfied: tiktoken>=0.3.3 in c:\conda\envs\sql_bot\lib\site-packages (from llama-index-core<0.12.0,>=0.11.0->llama-index-agent-openai) (0.7.0)
# Requirement already satisfied: tqdm<5.0.0,>=4.66.1 in c:\conda\envs\sql_bot\lib\site-packages (from llama-index-core<0.12.0,>=0.11.0->llama-index-agent-openai) (4.66.5)
# Requirement already satisfied: typing-extensions>=4.5.0 in c:\conda\envs\sql_bot\lib\site-packages (from llama-index-core<0.12.0,>=0.11.0->llama-index-agent-openai) (4.12.2)
# Requirement already satisfied: typing-inspect>=0.8.0 in c:\conda\envs\sql_bot\lib\site-packages (from llama-index-core<0.12.0,>=0.11.0->llama-index-agent-openai) (0.9.0)
# Requirement already satisfied: wrapt in c:\conda\envs\sql_bot\lib\site-packages (from llama-index-core<0.12.0,>=0.11.0->llama-index-agent-openai) (1.16.0)
# Requirement already satisfied: anyio<5,>=3.5.0 in c:\conda\envs\sql_bot\lib\site-packages (from openai>=1.14.0->llama-index-agent-openai) (4.4.0)
# Requirement already satisfied: distro<2,>=1.7.0 in c:\conda\envs\sql_bot\lib\site-packages (from openai>=1.14.0->llama-index-agent-openai) (1.9.0)
# Requirement already satisfied: jiter<1,>=0.4.0 in c:\conda\envs\sql_bot\lib\site-packages (from openai>=1.14.0->llama-index-agent-openai) (0.5.0)
# Requirement already satisfied: sniffio in c:\conda\envs\sql_bot\lib\site-packages (from openai>=1.14.0->llama-index-agent-openai) (1.3.1)
# Requirement already satisfied: aiohappyeyeballs>=2.3.0 in c:\conda\envs\sql_bot\lib\site-packages (from aiohttp<4.0.0,>=3.8.6->llama-index-core<0.12.0,>=0.11.0->llama-index-agent-openai) (2.4.0)
# Requirement already satisfied: aiosignal>=1.1.2 in c:\conda\envs\sql_bot\lib\site-packages (from aiohttp<4.0.0,>=3.8.6->llama-index-core<0.12.0,>=0.11.0->llama-index-agent-openai) (1.3.1)
# Requirement already satisfied: attrs>=17.3.0 in c:\conda\envs\sql_bot\lib\site-packages (from aiohttp<4.0.0,>=3.8.6->llama-index-core<0.12.0,>=0.11.0->llama-index-agent-openai) (24.2.0)
# Requirement already satisfied: frozenlist>=1.1.1 in c:\conda\envs\sql_bot\lib\site-packages (from aiohttp<4.0.0,>=3.8.6->llama-index-core<0.12.0,>=0.11.0->llama-index-agent-openai) (1.4.1)
# Requirement already satisfied: multidict<7.0,>=4.5 in c:\conda\envs\sql_bot\lib\site-packages (from aiohttp<4.0.0,>=3.8.6->llama-index-core<0.12.0,>=0.11.0->llama-index-agent-openai) (6.0.5)
# Requirement already satisfied: yarl<2.0,>=1.0 in c:\conda\envs\sql_bot\lib\site-packages (from aiohttp<4.0.0,>=3.8.6->llama-index-core<0.12.0,>=0.11.0->llama-index-agent-openai) (1.9.9)
# Requirement already satisfied: idna>=2.8 in c:\conda\envs\sql_bot\lib\site-packages (from anyio<5,>=3.5.0->openai>=1.14.0->llama-index-agent-openai) (3.8)
# Requirement already satisfied: certifi in c:\conda\envs\sql_bot\lib\site-packages (from httpx->llama-index-core<0.12.0,>=0.11.0->llama-index-agent-openai) (2024.8.30)
# Requirement already satisfied: httpcore==1.* in c:\conda\envs\sql_bot\lib\site-packages (from httpx->llama-index-core<0.12.0,>=0.11.0->llama-index-agent-openai) (1.0.5)
# Requirement already satisfied: h11<0.15,>=0.13 in c:\conda\envs\sql_bot\lib\site-packages (from httpcore==1.*->httpx->llama-index-core<0.12.0,>=0.11.0->llama-index-agent-openai) (0.14.0)
# Requirement already satisfied: click in c:\conda\envs\sql_bot\lib\site-packages (from nltk>3.8.1->llama-index-core<0.12.0,>=0.11.0->llama-index-agent-openai) (8.1.7)
# Requirement already satisfied: joblib in c:\conda\envs\sql_bot\lib\site-packages (from nltk>3.8.1->llama-index-core<0.12.0,>=0.11.0->llama-index-agent-openai) (1.4.2)
# Requirement already satisfied: regex>=2021.8.3 in c:\conda\envs\sql_bot\lib\site-packages (from nltk>3.8.1->llama-index-core<0.12.0,>=0.11.0->llama-index-agent-openai) (2024.7.24)
# Requirement already satisfied: annotated-types>=0.4.0 in c:\conda\envs\sql_bot\lib\site-packages (from pydantic<3.0.0,>=2.7.0->llama-index-core<0.12.0,>=0.11.0->llama-index-agent-openai) (0.7.0)
# Requirement already satisfied: pydantic-core==2.20.1 in c:\conda\envs\sql_bot\lib\site-packages (from pydantic<3.0.0,>=2.7.0->llama-index-core<0.12.0,>=0.11.0->llama-index-agent-openai) (2.20.1)
# Requirement already satisfied: charset-normalizer<4,>=2 in c:\conda\envs\sql_bot\lib\site-packages (from requests>=2.31.0->llama-index-core<0.12.0,>=0.11.0->llama-index-agent-openai) (3.3.2)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\conda\envs\sql_bot\lib\site-packages (from requests>=2.31.0->llama-index-core<0.12.0,>=0.11.0->llama-index-agent-openai) (2.2.2)
# Requirement already satisfied: greenlet!=0.4.17 in c:\conda\envs\sql_bot\lib\site-packages (from SQLAlchemy>=1.4.49->SQLAlchemy[asyncio]>=1.4.49->llama-index-core<0.12.0,>=0.11.0->llama-index-agent-openai) (3.0.3)
# Requirement already satisfied: colorama in c:\conda\envs\sql_bot\lib\site-packages (from tqdm<5.0.0,>=4.66.1->llama-index-core<0.12.0,>=0.11.0->llama-index-agent-openai) (0.4.6)
# Requirement already satisfied: mypy-extensions>=0.3.0 in c:\conda\envs\sql_bot\lib\site-packages (from typing-inspect>=0.8.0->llama-index-core<0.12.0,>=0.11.0->llama-index-agent-openai) (1.0.0)
# Requirement already satisfied: marshmallow<4.0.0,>=3.18.0 in c:\conda\envs\sql_bot\lib\site-packages (from dataclasses-json->llama-index-core<0.12.0,>=0.11.0->llama-index-agent-openai) (3.22.0)
# Requirement already satisfied: packaging>=17.0 in c:\conda\envs\sql_bot\lib\site-packages (from marshmallow<4.0.0,>=3.18.0->dataclasses-json->llama-index-core<0.12.0,>=0.11.0->llama-index-agent-openai) (24.1)
# Note: you may need to restart the kernel to use updated packages.
# Requirement already satisfied: llama-index-embeddings-openai in c:\conda\envs\sql_bot\lib\site-packages (0.2.4)
# Requirement already satisfied: llama-index-core<0.12.0,>=0.11.0 in c:\conda\envs\sql_bot\lib\site-packages (from llama-index-embeddings-openai) (0.11.5)
# Requirement already satisfied: openai>=1.1.0 in c:\conda\envs\sql_bot\lib\site-packages (from llama-index-embeddings-openai) (1.43.0)
# Requirement already satisfied: PyYAML>=6.0.1 in c:\conda\envs\sql_bot\lib\site-packages (from llama-index-core<0.12.0,>=0.11.0->llama-index-embeddings-openai) (6.0.2)
# Requirement already satisfied: SQLAlchemy>=1.4.49 in c:\conda\envs\sql_bot\lib\site-packages (from SQLAlchemy[asyncio]>=1.4.49->llama-index-core<0.12.0,>=0.11.0->llama-index-embeddings-openai) (2.0.34)
# Requirement already satisfied: aiohttp<4.0.0,>=3.8.6 in c:\conda\envs\sql_bot\lib\site-packages (from llama-index-core<0.12.0,>=0.11.0->llama-index-embeddings-openai) (3.10.5)
# Requirement already satisfied: dataclasses-json in c:\conda\envs\sql_bot\lib\site-packages (from llama-index-core<0.12.0,>=0.11.0->llama-index-embeddings-openai) (0.6.7)
# Requirement already satisfied: deprecated>=1.2.9.3 in c:\conda\envs\sql_bot\lib\site-packages (from llama-index-core<0.12.0,>=0.11.0->llama-index-embeddings-openai) (1.2.14)
# Requirement already satisfied: dirtyjson<2.0.0,>=1.0.8 in c:\conda\envs\sql_bot\lib\site-packages (from llama-index-core<0.12.0,>=0.11.0->llama-index-embeddings-openai) (1.0.8)
# Requirement already satisfied: fsspec>=2023.5.0 in c:\conda\envs\sql_bot\lib\site-packages (from llama-index-core<0.12.0,>=0.11.0->llama-index-embeddings-openai) (2024.9.0)
# Requirement already satisfied: httpx in c:\conda\envs\sql_bot\lib\site-packages (from llama-index-core<0.12.0,>=0.11.0->llama-index-embeddings-openai) (0.27.2)
# Requirement already satisfied: nest-asyncio<2.0.0,>=1.5.8 in c:\conda\envs\sql_bot\lib\site-packages (from llama-index-core<0.12.0,>=0.11.0->llama-index-embeddings-openai) (1.6.0)
# Requirement already satisfied: networkx>=3.0 in c:\conda\envs\sql_bot\lib\site-packages (from llama-index-core<0.12.0,>=0.11.0->llama-index-embeddings-openai) (3.3)
# Requirement already satisfied: nltk>3.8.1 in c:\conda\envs\sql_bot\lib\site-packages (from llama-index-core<0.12.0,>=0.11.0->llama-index-embeddings-openai) (3.9.1)
# Requirement already satisfied: numpy<2.0.0 in c:\conda\envs\sql_bot\lib\site-packages (from llama-index-core<0.12.0,>=0.11.0->llama-index-embeddings-openai) (1.26.4)
# Requirement already satisfied: pillow>=9.0.0 in c:\conda\envs\sql_bot\lib\site-packages (from llama-index-core<0.12.0,>=0.11.0->llama-index-embeddings-openai) (10.4.0)
# Requirement already satisfied: pydantic<3.0.0,>=2.7.0 in c:\conda\envs\sql_bot\lib\site-packages (from llama-index-core<0.12.0,>=0.11.0->llama-index-embeddings-openai) (2.8.2)
# Requirement already satisfied: requests>=2.31.0 in c:\conda\envs\sql_bot\lib\site-packages (from llama-index-core<0.12.0,>=0.11.0->llama-index-embeddings-openai) (2.32.3)
# Requirement already satisfied: tenacity!=8.4.0,<9.0.0,>=8.2.0 in c:\conda\envs\sql_bot\lib\site-packages (from llama-index-core<0.12.0,>=0.11.0->llama-index-embeddings-openai) (8.5.0)
# Requirement already satisfied: tiktoken>=0.3.3 in c:\conda\envs\sql_bot\lib\site-packages (from llama-index-core<0.12.0,>=0.11.0->llama-index-embeddings-openai) (0.7.0)
# Requirement already satisfied: tqdm<5.0.0,>=4.66.1 in c:\conda\envs\sql_bot\lib\site-packages (from llama-index-core<0.12.0,>=0.11.0->llama-index-embeddings-openai) (4.66.5)
# Requirement already satisfied: typing-extensions>=4.5.0 in c:\conda\envs\sql_bot\lib\site-packages (from llama-index-core<0.12.0,>=0.11.0->llama-index-embeddings-openai) (4.12.2)
# Requirement already satisfied: typing-inspect>=0.8.0 in c:\conda\envs\sql_bot\lib\site-packages (from llama-index-core<0.12.0,>=0.11.0->llama-index-embeddings-openai) (0.9.0)
# Requirement already satisfied: wrapt in c:\conda\envs\sql_bot\lib\site-packages (from llama-index-core<0.12.0,>=0.11.0->llama-index-embeddings-openai) (1.16.0)
# Requirement already satisfied: anyio<5,>=3.5.0 in c:\conda\envs\sql_bot\lib\site-packages (from openai>=1.1.0->llama-index-embeddings-openai) (4.4.0)
# Requirement already satisfied: distro<2,>=1.7.0 in c:\conda\envs\sql_bot\lib\site-packages (from openai>=1.1.0->llama-index-embeddings-openai) (1.9.0)
# Requirement already satisfied: jiter<1,>=0.4.0 in c:\conda\envs\sql_bot\lib\site-packages (from openai>=1.1.0->llama-index-embeddings-openai) (0.5.0)
# Requirement already satisfied: sniffio in c:\conda\envs\sql_bot\lib\site-packages (from openai>=1.1.0->llama-index-embeddings-openai) (1.3.1)
# Requirement already satisfied: aiohappyeyeballs>=2.3.0 in c:\conda\envs\sql_bot\lib\site-packages (from aiohttp<4.0.0,>=3.8.6->llama-index-core<0.12.0,>=0.11.0->llama-index-embeddings-openai) (2.4.0)
# Requirement already satisfied: aiosignal>=1.1.2 in c:\conda\envs\sql_bot\lib\site-packages (from aiohttp<4.0.0,>=3.8.6->llama-index-core<0.12.0,>=0.11.0->llama-index-embeddings-openai) (1.3.1)
# Requirement already satisfied: attrs>=17.3.0 in c:\conda\envs\sql_bot\lib\site-packages (from aiohttp<4.0.0,>=3.8.6->llama-index-core<0.12.0,>=0.11.0->llama-index-embeddings-openai) (24.2.0)
# Requirement already satisfied: frozenlist>=1.1.1 in c:\conda\envs\sql_bot\lib\site-packages (from aiohttp<4.0.0,>=3.8.6->llama-index-core<0.12.0,>=0.11.0->llama-index-embeddings-openai) (1.4.1)
# Requirement already satisfied: multidict<7.0,>=4.5 in c:\conda\envs\sql_bot\lib\site-packages (from aiohttp<4.0.0,>=3.8.6->llama-index-core<0.12.0,>=0.11.0->llama-index-embeddings-openai) (6.0.5)
# Requirement already satisfied: yarl<2.0,>=1.0 in c:\conda\envs\sql_bot\lib\site-packages (from aiohttp<4.0.0,>=3.8.6->llama-index-core<0.12.0,>=0.11.0->llama-index-embeddings-openai) (1.9.9)
# Requirement already satisfied: idna>=2.8 in c:\conda\envs\sql_bot\lib\site-packages (from anyio<5,>=3.5.0->openai>=1.1.0->llama-index-embeddings-openai) (3.8)
# Requirement already satisfied: certifi in c:\conda\envs\sql_bot\lib\site-packages (from httpx->llama-index-core<0.12.0,>=0.11.0->llama-index-embeddings-openai) (2024.8.30)
# Requirement already satisfied: httpcore==1.* in c:\conda\envs\sql_bot\lib\site-packages (from httpx->llama-index-core<0.12.0,>=0.11.0->llama-index-embeddings-openai) (1.0.5)
# Requirement already satisfied: h11<0.15,>=0.13 in c:\conda\envs\sql_bot\lib\site-packages (from httpcore==1.*->httpx->llama-index-core<0.12.0,>=0.11.0->llama-index-embeddings-openai) (0.14.0)
# Requirement already satisfied: click in c:\conda\envs\sql_bot\lib\site-packages (from nltk>3.8.1->llama-index-core<0.12.0,>=0.11.0->llama-index-embeddings-openai) (8.1.7)
# Requirement already satisfied: joblib in c:\conda\envs\sql_bot\lib\site-packages (from nltk>3.8.1->llama-index-core<0.12.0,>=0.11.0->llama-index-embeddings-openai) (1.4.2)
# Requirement already satisfied: regex>=2021.8.3 in c:\conda\envs\sql_bot\lib\site-packages (from nltk>3.8.1->llama-index-core<0.12.0,>=0.11.0->llama-index-embeddings-openai) (2024.7.24)
# Requirement already satisfied: annotated-types>=0.4.0 in c:\conda\envs\sql_bot\lib\site-packages (from pydantic<3.0.0,>=2.7.0->llama-index-core<0.12.0,>=0.11.0->llama-index-embeddings-openai) (0.7.0)
# Requirement already satisfied: pydantic-core==2.20.1 in c:\conda\envs\sql_bot\lib\site-packages (from pydantic<3.0.0,>=2.7.0->llama-index-core<0.12.0,>=0.11.0->llama-index-embeddings-openai) (2.20.1)
# Requirement already satisfied: charset-normalizer<4,>=2 in c:\conda\envs\sql_bot\lib\site-packages (from requests>=2.31.0->llama-index-core<0.12.0,>=0.11.0->llama-index-embeddings-openai) (3.3.2)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\conda\envs\sql_bot\lib\site-packages (from requests>=2.31.0->llama-index-core<0.12.0,>=0.11.0->llama-index-embeddings-openai) (2.2.2)
# Requirement already satisfied: greenlet!=0.4.17 in c:\conda\envs\sql_bot\lib\site-packages (from SQLAlchemy>=1.4.49->SQLAlchemy[asyncio]>=1.4.49->llama-index-core<0.12.0,>=0.11.0->llama-index-embeddings-openai) (3.0.3)
# Requirement already satisfied: colorama in c:\conda\envs\sql_bot\lib\site-packages (from tqdm<5.0.0,>=4.66.1->llama-index-core<0.12.0,>=0.11.0->llama-index-embeddings-openai) (0.4.6)
# Requirement already satisfied: mypy-extensions>=0.3.0 in c:\conda\envs\sql_bot\lib\site-packages (from typing-inspect>=0.8.0->llama-index-core<0.12.0,>=0.11.0->llama-index-embeddings-openai) (1.0.0)
# Requirement already satisfied: marshmallow<4.0.0,>=3.18.0 in c:\conda\envs\sql_bot\lib\site-packages (from dataclasses-json->llama-index-core<0.12.0,>=0.11.0->llama-index-embeddings-openai) (3.22.0)
# Requirement already satisfied: packaging>=17.0 in c:\conda\envs\sql_bot\lib\site-packages (from marshmallow<4.0.0,>=3.18.0->dataclasses-json->llama-index-core<0.12.0,>=0.11.0->llama-index-embeddings-openai) (24.1)
# Note: you may need to restart the kernel to use updated packages.
# Requirement already satisfied: llama-index-llms-openai in c:\conda\envs\sql_bot\lib\site-packages (0.2.2)Note: you may need to restart the kernel to use updated packages.
#
# Requirement already satisfied: llama-index-agent-openai<0.4.0,>=0.3.0 in c:\conda\envs\sql_bot\lib\site-packages (from llama-index-llms-openai) (0.3.0)
# Requirement already satisfied: llama-index-core<0.12.0,>=0.11.0 in c:\conda\envs\sql_bot\lib\site-packages (from llama-index-llms-openai) (0.11.5)
# Requirement already satisfied: openai<2.0.0,>=1.40.0 in c:\conda\envs\sql_bot\lib\site-packages (from llama-index-llms-openai) (1.43.0)
# Requirement already satisfied: PyYAML>=6.0.1 in c:\conda\envs\sql_bot\lib\site-packages (from llama-index-core<0.12.0,>=0.11.0->llama-index-llms-openai) (6.0.2)
# Requirement already satisfied: SQLAlchemy>=1.4.49 in c:\conda\envs\sql_bot\lib\site-packages (from SQLAlchemy[asyncio]>=1.4.49->llama-index-core<0.12.0,>=0.11.0->llama-index-llms-openai) (2.0.34)
# Requirement already satisfied: aiohttp<4.0.0,>=3.8.6 in c:\conda\envs\sql_bot\lib\site-packages (from llama-index-core<0.12.0,>=0.11.0->llama-index-llms-openai) (3.10.5)
# Requirement already satisfied: dataclasses-json in c:\conda\envs\sql_bot\lib\site-packages (from llama-index-core<0.12.0,>=0.11.0->llama-index-llms-openai) (0.6.7)
# Requirement already satisfied: deprecated>=1.2.9.3 in c:\conda\envs\sql_bot\lib\site-packages (from llama-index-core<0.12.0,>=0.11.0->llama-index-llms-openai) (1.2.14)
# Requirement already satisfied: dirtyjson<2.0.0,>=1.0.8 in c:\conda\envs\sql_bot\lib\site-packages (from llama-index-core<0.12.0,>=0.11.0->llama-index-llms-openai) (1.0.8)
# Requirement already satisfied: fsspec>=2023.5.0 in c:\conda\envs\sql_bot\lib\site-packages (from llama-index-core<0.12.0,>=0.11.0->llama-index-llms-openai) (2024.9.0)
# Requirement already satisfied: httpx in c:\conda\envs\sql_bot\lib\site-packages (from llama-index-core<0.12.0,>=0.11.0->llama-index-llms-openai) (0.27.2)
# Requirement already satisfied: nest-asyncio<2.0.0,>=1.5.8 in c:\conda\envs\sql_bot\lib\site-packages (from llama-index-core<0.12.0,>=0.11.0->llama-index-llms-openai) (1.6.0)
# Requirement already satisfied: networkx>=3.0 in c:\conda\envs\sql_bot\lib\site-packages (from llama-index-core<0.12.0,>=0.11.0->llama-index-llms-openai) (3.3)
# Requirement already satisfied: nltk>3.8.1 in c:\conda\envs\sql_bot\lib\site-packages (from llama-index-core<0.12.0,>=0.11.0->llama-index-llms-openai) (3.9.1)
# Requirement already satisfied: numpy<2.0.0 in c:\conda\envs\sql_bot\lib\site-packages (from llama-index-core<0.12.0,>=0.11.0->llama-index-llms-openai) (1.26.4)
# Requirement already satisfied: pillow>=9.0.0 in c:\conda\envs\sql_bot\lib\site-packages (from llama-index-core<0.12.0,>=0.11.0->llama-index-llms-openai) (10.4.0)
# Requirement already satisfied: pydantic<3.0.0,>=2.7.0 in c:\conda\envs\sql_bot\lib\site-packages (from llama-index-core<0.12.0,>=0.11.0->llama-index-llms-openai) (2.8.2)
# Requirement already satisfied: requests>=2.31.0 in c:\conda\envs\sql_bot\lib\site-packages (from llama-index-core<0.12.0,>=0.11.0->llama-index-llms-openai) (2.32.3)
# Requirement already satisfied: tenacity!=8.4.0,<9.0.0,>=8.2.0 in c:\conda\envs\sql_bot\lib\site-packages (from llama-index-core<0.12.0,>=0.11.0->llama-index-llms-openai) (8.5.0)
# Requirement already satisfied: tiktoken>=0.3.3 in c:\conda\envs\sql_bot\lib\site-packages (from llama-index-core<0.12.0,>=0.11.0->llama-index-llms-openai) (0.7.0)
# Requirement already satisfied: tqdm<5.0.0,>=4.66.1 in c:\conda\envs\sql_bot\lib\site-packages (from llama-index-core<0.12.0,>=0.11.0->llama-index-llms-openai) (4.66.5)
# Requirement already satisfied: typing-extensions>=4.5.0 in c:\conda\envs\sql_bot\lib\site-packages (from llama-index-core<0.12.0,>=0.11.0->llama-index-llms-openai) (4.12.2)
# Requirement already satisfied: typing-inspect>=0.8.0 in c:\conda\envs\sql_bot\lib\site-packages (from llama-index-core<0.12.0,>=0.11.0->llama-index-llms-openai) (0.9.0)
# Requirement already satisfied: wrapt in c:\conda\envs\sql_bot\lib\site-packages (from llama-index-core<0.12.0,>=0.11.0->llama-index-llms-openai) (1.16.0)
# Requirement already satisfied: anyio<5,>=3.5.0 in c:\conda\envs\sql_bot\lib\site-packages (from openai<2.0.0,>=1.40.0->llama-index-llms-openai) (4.4.0)
# Requirement already satisfied: distro<2,>=1.7.0 in c:\conda\envs\sql_bot\lib\site-packages (from openai<2.0.0,>=1.40.0->llama-index-llms-openai) (1.9.0)
# Requirement already satisfied: jiter<1,>=0.4.0 in c:\conda\envs\sql_bot\lib\site-packages (from openai<2.0.0,>=1.40.0->llama-index-llms-openai) (0.5.0)
# Requirement already satisfied: sniffio in c:\conda\envs\sql_bot\lib\site-packages (from openai<2.0.0,>=1.40.0->llama-index-llms-openai) (1.3.1)
# Requirement already satisfied: aiohappyeyeballs>=2.3.0 in c:\conda\envs\sql_bot\lib\site-packages (from aiohttp<4.0.0,>=3.8.6->llama-index-core<0.12.0,>=0.11.0->llama-index-llms-openai) (2.4.0)
# Requirement already satisfied: aiosignal>=1.1.2 in c:\conda\envs\sql_bot\lib\site-packages (from aiohttp<4.0.0,>=3.8.6->llama-index-core<0.12.0,>=0.11.0->llama-index-llms-openai) (1.3.1)
# Requirement already satisfied: attrs>=17.3.0 in c:\conda\envs\sql_bot\lib\site-packages (from aiohttp<4.0.0,>=3.8.6->llama-index-core<0.12.0,>=0.11.0->llama-index-llms-openai) (24.2.0)
# Requirement already satisfied: frozenlist>=1.1.1 in c:\conda\envs\sql_bot\lib\site-packages (from aiohttp<4.0.0,>=3.8.6->llama-index-core<0.12.0,>=0.11.0->llama-index-llms-openai) (1.4.1)
# Requirement already satisfied: multidict<7.0,>=4.5 in c:\conda\envs\sql_bot\lib\site-packages (from aiohttp<4.0.0,>=3.8.6->llama-index-core<0.12.0,>=0.11.0->llama-index-llms-openai) (6.0.5)
# Requirement already satisfied: yarl<2.0,>=1.0 in c:\conda\envs\sql_bot\lib\site-packages (from aiohttp<4.0.0,>=3.8.6->llama-index-core<0.12.0,>=0.11.0->llama-index-llms-openai) (1.9.9)
# Requirement already satisfied: idna>=2.8 in c:\conda\envs\sql_bot\lib\site-packages (from anyio<5,>=3.5.0->openai<2.0.0,>=1.40.0->llama-index-llms-openai) (3.8)
# Requirement already satisfied: certifi in c:\conda\envs\sql_bot\lib\site-packages (from httpx->llama-index-core<0.12.0,>=0.11.0->llama-index-llms-openai) (2024.8.30)
# Requirement already satisfied: httpcore==1.* in c:\conda\envs\sql_bot\lib\site-packages (from httpx->llama-index-core<0.12.0,>=0.11.0->llama-index-llms-openai) (1.0.5)
# Requirement already satisfied: h11<0.15,>=0.13 in c:\conda\envs\sql_bot\lib\site-packages (from httpcore==1.*->httpx->llama-index-core<0.12.0,>=0.11.0->llama-index-llms-openai) (0.14.0)
# Requirement already satisfied: click in c:\conda\envs\sql_bot\lib\site-packages (from nltk>3.8.1->llama-index-core<0.12.0,>=0.11.0->llama-index-llms-openai) (8.1.7)
# Requirement already satisfied: joblib in c:\conda\envs\sql_bot\lib\site-packages (from nltk>3.8.1->llama-index-core<0.12.0,>=0.11.0->llama-index-llms-openai) (1.4.2)
# Requirement already satisfied: regex>=2021.8.3 in c:\conda\envs\sql_bot\lib\site-packages (from nltk>3.8.1->llama-index-core<0.12.0,>=0.11.0->llama-index-llms-openai) (2024.7.24)
# Requirement already satisfied: annotated-types>=0.4.0 in c:\conda\envs\sql_bot\lib\site-packages (from pydantic<3.0.0,>=2.7.0->llama-index-core<0.12.0,>=0.11.0->llama-index-llms-openai) (0.7.0)
# Requirement already satisfied: pydantic-core==2.20.1 in c:\conda\envs\sql_bot\lib\site-packages (from pydantic<3.0.0,>=2.7.0->llama-index-core<0.12.0,>=0.11.0->llama-index-llms-openai) (2.20.1)
# Requirement already satisfied: charset-normalizer<4,>=2 in c:\conda\envs\sql_bot\lib\site-packages (from requests>=2.31.0->llama-index-core<0.12.0,>=0.11.0->llama-index-llms-openai) (3.3.2)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\conda\envs\sql_bot\lib\site-packages (from requests>=2.31.0->llama-index-core<0.12.0,>=0.11.0->llama-index-llms-openai) (2.2.2)
# Requirement already satisfied: greenlet!=0.4.17 in c:\conda\envs\sql_bot\lib\site-packages (from SQLAlchemy>=1.4.49->SQLAlchemy[asyncio]>=1.4.49->llama-index-core<0.12.0,>=0.11.0->llama-index-llms-openai) (3.0.3)
# Requirement already satisfied: colorama in c:\conda\envs\sql_bot\lib\site-packages (from tqdm<5.0.0,>=4.66.1->llama-index-core<0.12.0,>=0.11.0->llama-index-llms-openai) (0.4.6)
# Requirement already satisfied: mypy-extensions>=0.3.0 in c:\conda\envs\sql_bot\lib\site-packages (from typing-inspect>=0.8.0->llama-index-core<0.12.0,>=0.11.0->llama-index-llms-openai) (1.0.0)
# Requirement already satisfied: marshmallow<4.0.0,>=3.18.0 in c:\conda\envs\sql_bot\lib\site-packages (from dataclasses-json->llama-index-core<0.12.0,>=0.11.0->llama-index-llms-openai) (3.22.0)
# Requirement already satisfied: packaging>=17.0 in c:\conda\envs\sql_bot\lib\site-packages (from marshmallow<4.0.0,>=3.18.0->dataclasses-json->llama-index-core<0.12.0,>=0.11.0->llama-index-llms-openai) (24.1)

# %%
from llama_index.core import (
    VectorStoreIndex,
    SimpleKeywordTableIndex,
    SimpleDirectoryReader,
)
from llama_index.core import SummaryIndex
from llama_index.core.schema import IndexNode
from llama_index.core.tools import QueryEngineTool, ToolMetadata
from llama_index.llms.openai import OpenAI
from llama_index.core.callbacks import CallbackManager

# %%
wiki_titles = [
    "Toronto",
    "Seattle",
    "Chicago",
    "Boston",
    "Houston",
    "Tokyo",
    "Berlin",
    "Lisbon",
    "Paris",
    "London",
    "Atlanta",
    "Munich",
    "Shanghai",
    "Beijing",
    "Copenhagen",
    "Moscow",
    "Cairo",
    "Karachi",
]

# %%
from pathlib import Path

import requests

for title in wiki_titles:
    response = requests.get(
        "https://en.wikipedia.org/w/api.php",
        params={
            "action": "query",
            "format": "json",
            "titles": title,
            "prop": "extracts",
            # 'exintro': True,
            "explaintext": True,
        },
    ).json()
    page = next(iter(response["query"]["pages"].values()))
    wiki_text = page["extract"]

    data_path = Path("data")
    if not data_path.exists():
        Path.mkdir(data_path)

    with open(data_path / f"{title}.txt", "w") as fp:
        fp.write(wiki_text)

# %%
# Load all wiki documents
city_docs = {}
for wiki_title in wiki_titles:
    city_docs[wiki_title] = SimpleDirectoryReader(
        input_files=[f"data/{wiki_title}.txt"]
    ).load_data()

# %%
from llama_index.llms.groq import Groq
from llama_index.embeddings.openai import OpenAIEmbedding
from llama_index.embeddings.huggingface import HuggingFaceEmbedding
from llama_index.core import Settings

Settings.llm = Groq(model="llama3-8b-8192")
Settings.embed_model = HuggingFaceEmbedding(model_name="BAAI/bge-small-en-v1.5")

# %%
from llama_index.agent.openai import OpenAIAgent
from llama_index.core import load_index_from_storage, StorageContext
from llama_index.core.node_parser import SentenceSplitter
import os

node_parser = SentenceSplitter()

# Build agents dictionary
agents = {}
query_engines = {}

# this is for the baseline
all_nodes = []

for idx, wiki_title in enumerate(wiki_titles):
    nodes = node_parser.get_nodes_from_documents(city_docs[wiki_title])
    all_nodes.extend(nodes)

    if not os.path.exists(f"./data/{wiki_title}"):
        # build vector index
        vector_index = VectorStoreIndex(nodes)
        vector_index.storage_context.persist(
            persist_dir=f"./data/{wiki_title}"
        )
    else:
        vector_index = load_index_from_storage(
            StorageContext.from_defaults(persist_dir=f"./data/{wiki_title}"),
        )

    # build summary index
    summary_index = SummaryIndex(nodes)
    # define query engines
    vector_query_engine = vector_index.as_query_engine(llm=Settings.llm)
    summary_query_engine = summary_index.as_query_engine(llm=Settings.llm)

    # define tools
    query_engine_tools = [
        QueryEngineTool(
            query_engine=vector_query_engine,
            metadata=ToolMetadata(
                name="vector_tool",
                description=(
                    "Useful for questions related to specific aspects of"
                    f" {wiki_title} (e.g. the history, arts and culture,"
                    " sports, demographics, or more)."
                ),
            ),
        ),
        QueryEngineTool(
            query_engine=summary_query_engine,
            metadata=ToolMetadata(
                name="summary_tool",
                description=(
                    "Useful for any requests that require a holistic summary"
                    f" of EVERYTHING about {wiki_title}. For questions about"
                    " more specific sections, please use the vector_tool."
                ),
            ),
        ),
    ]

    # build agent
    function_llm = Groq(model='llama3-70b-8192')
    agent = OpenAIAgent.from_tools(
        query_engine_tools,
        llm=function_llm,
        verbose=True,
        system_prompt=f"""\
You are a specialized agent designed to answer queries about {wiki_title}.
You must ALWAYS use at least one of the tools provided when answering a question; do NOT rely on prior knowledge.\
""",
    )

    agents[wiki_title] = agent
    query_engines[wiki_title] = vector_index.as_query_engine(
        similarity_top_k=2
    )

# %%
# define tool for each document agent
all_tools = []
for wiki_title in wiki_titles:
    wiki_summary = (
        f"This content contains Wikipedia articles about {wiki_title}. Use"
        f" this tool if you want to answer any questions about {wiki_title}.\n"
    )
    doc_tool = QueryEngineTool(
        query_engine=agents[wiki_title],
        metadata=ToolMetadata(
            name=f"tool_{wiki_title}",
            description=wiki_summary,
        ),
    )
    all_tools.append(doc_tool)

# %%
# define an "object" index and retriever over these tools
from llama_index.core import VectorStoreIndex
from llama_index.core.objects import ObjectIndex

obj_index = ObjectIndex.from_objects(
    all_tools,
    index_cls=VectorStoreIndex,
)

# %%
from llama_index.agent.openai import OpenAIAgent

top_agent = OpenAIAgent.from_tools(
    tool_retriever=obj_index.as_retriever(similarity_top_k=3),
    system_prompt=""" \
You are an agent designed to answer queries about a set of given cities.
Please always use the tools provided to answer a question. Do not rely on prior knowledge.\

""",
    verbose=True,
)

# %%
base_index = VectorStoreIndex(all_nodes)
base_query_engine = base_index.as_query_engine(similarity_top_k=4)

# %%
# should use Boston agent -> vector tool
response = top_agent.query("Tell me about the arts and culture in Boston")
# Out:
# Added user message to memory: Tell me about the arts and culture in Boston
# === Calling Function ===
# Calling function: tool_Boston with args: {"input":"arts and culture in Boston"}
# Added user message to memory: arts and culture in Boston
# === Calling Function ===
# Calling function: vector_tool with args: {"input":"arts and culture in Boston"}
# Got output: Boston's literary culture continues today thanks to the city's many universities and the Boston Book Festival. Music is afforded a high degree of civic support in Boston. The city is a center for contemporary classical music with a number of performing groups, several of which are associated with the city's conservatories and universities. These include the Boston Modern Orchestra Project and Boston Musica Viva. Several theaters are in or near the Theater District south of Boston Common, including the Cutler Majestic Theatre, Citi Performing Arts Center, the Colonial Theater, and the Orpheum Theatre. The city is also home to several art museums and galleries, including the Museum of Fine Arts and the Isabella Stewart Gardner Museum. The Institute of Contemporary Art is housed in a contemporary building designed by Diller Scofidio + Renfro in the Seaport District. Boston's South End Art and Design District (SoWa) and Newbury St. are both art gallery destinations.
# ========================
#
# Got output: Here's a summary of arts and culture in Boston based on the tool's output:
#
# Boston is a hub for literary culture, with many universities and the Boston Book Festival contributing to its vibrant scene. The city is also a center for contemporary classical music, with several performing groups associated with local conservatories and universities. The Theater District is home to several historic theaters, including the Cutler Majestic Theatre and the Orpheum Theatre. Boston is also renowned for its art museums and galleries, such as the Museum of Fine Arts, the Isabella Stewart Gardner Museum, and the Institute of Contemporary Art. The South End Art and Design District and Newbury St. are popular destinations for art enthusiasts.
# ========================
